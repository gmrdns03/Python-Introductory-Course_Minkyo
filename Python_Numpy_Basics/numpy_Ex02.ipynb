# %%
import numpy as np

# %%
array1 = np.array([2,3,5,7,11,13,15,17,19,23])

# %%
array1
# Out:
# array([ 2,  3,  5,  7, 11, 13, 15, 17, 19, 23])

# %%
array1[0] 
#0번째 인덱스값 불러오기
# Out:
# 2

# %%
array1[5]
# Out:
# 13

# %%
array1[-1]
# Out:
# 23

# %%
array1[[1,3,4]]  
#리스트 안에 리스트 넣어서 인덱스값 불러오기
# Out:
# array([ 3,  7, 11])

# %%
array2 = np.array([2,1,3])

# %%
array1[array2]  
#다른 어레이로 인덱싱 하기
# Out:
# array([5, 3, 7])

# %%
array1[2:7]
# Out:
# array([ 5,  7, 11, 13, 15])

# %%
array1[2:6:3] 
#2번부터 6번 인덱스까지 숫자 세개씩 건너뛰며 불러오기
# Out:
# array([ 5, 13])
